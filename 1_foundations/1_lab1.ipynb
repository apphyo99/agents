# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('AZURE_API_KAY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins Aj0B6SrP

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI
from openai import AzureOpenAI

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role":"system", "content":"You are a helpful assistant"},{"role": "user", "content": "What is 2+2?"}]
deployment_name = "gpt-4o-mini"

client = AzureOpenAI(
    api_version="2024-12-01-preview",
    azure_endpoint=os.getenv("AZURE_API_ENDPOINT"),
    api_key=openai_api_key
)

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = client.chat.completions.create(
    messages = messages,
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment_name
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

def generate_chat_completion(messages, deployment_name, max_tokens=4096, temperature=1.0, top_p=1.0):
    """
    Generates a chat completion using Azure OpenAI.

    Args:
        messages (list): Conversation messages in OpenAI chat format.
        deployment_name (str): The model deployment name.
        max_tokens (int): Maximum tokens to generate.
        temperature (float): Sampling temperature.
        top_p (float): Nucleus sampling parameter.

    Returns:
        str: The model's reply text.
    """
    response = client.chat.completions.create(
        messages=messages,
        model=deployment_name,
        max_tokens=max_tokens,
        temperature=temperature,
        top_p=top_p
    )
    return response.choices[0].message.content

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

response_question = generate_chat_completion(messages, deployment_name )
print(response_question)
# Out:
# A train leaves Station A traveling at a speed of 60 miles per hour. At the same time, another train leaves Station B, 120 miles away, traveling towards Station A at a speed of 80 miles per hour. How far from Station A will the two trains meet?

# %%
# form a new messages list
messages = [{"role": "user", "content": response_question}]

# %%
# Ask it again

answer = generate_chat_completion(messages, deployment_name )
print(answer)
# Out:
# To solve the problem, we can determine how long it will take for the two trains to meet and then calculate the distance they each travel during that time.
#
# Let's denote:
# - Speed of Train A = 60 miles per hour
# - Speed of Train B = 80 miles per hour
# - Distance between Station A and Station B = 120 miles
#
# First, let's find the relative speed between the two trains as they are moving towards each other:
# \[
# \text{Relative speed} = \text{Speed of Train A} + \text{Speed of Train B} = 60 + 80 = 140 \text{ miles per hour}
# \]
#
# Next, we can calculate the time it will take for the trains to meet by dividing the total distance by the relative speed:
# \[
# \text{Time} = \frac{\text{Distance}}{\text{Relative speed}} = \frac{120 \text{ miles}}{140 \text{ miles per hour}} = \frac{12}{14} \text{ hours} = \frac{6}{7} \text{ hours}
# \]
#
# Now, we can find the distance that Train A travels in that time:
# \[
# \text{Distance traveled by Train A} = \text{Speed of Train A} \times \text{Time} = 60 \text{ miles per hour} \times \frac{6}{7} \text{ hours} = \frac{360}{7} \text{ miles} \approx 51.43 \text{ miles}
# \]
#
# Therefore, the two trains will meet approximately 51.43 miles from Station A.
#
# Thus, the answer is:
# \[
# \boxed{51.43 \text{ miles}}
# \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To solve the problem, we can determine how long it will take for the two trains to meet and then calculate the distance they each travel during that time.
#
# Let's denote:
# - Speed of Train A = 60 miles per hour
# - Speed of Train B = 80 miles per hour
# - Distance between Station A and Station B = 120 miles
#
# First, let's find the relative speed between the two trains as they are moving towards each other:
# \[
# \text{Relative speed} = \text{Speed of Train A} + \text{Speed of Train B} = 60 + 80 = 140 \text{ miles per hour}
# \]
#
# Next, we can calculate the time it will take for the trains to meet by dividing the total distance by the relative speed:
# \[
# \text{Time} = \frac{\text{Distance}}{\text{Relative speed}} = \frac{120 \text{ miles}}{140 \text{ miles per hour}} = \frac{12}{14} \text{ hours} = \frac{6}{7} \text{ hours}
# \]
#
# Now, we can find the distance that Train A travels in that time:
# \[
# \text{Distance traveled by Train A} = \text{Speed of Train A} \times \text{Time} = 60 \text{ miles per hour} \times \frac{6}{7} \text{ hours} = \frac{360}{7} \text{ miles} \approx 51.43 \text{ miles}
# \]
#
# Therefore, the two trains will meet approximately 51.43 miles from Station A.
#
# Thus, the answer is:
# \[
# \boxed{51.43 \text{ miles}}
# \]

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Give me a business area that might be worth exploring for an agentic AI opportunity?"}]

# Then make the first call:

response = generate_chat_completion(messages, deployment_name )

print(response)
# Out:
# One promising business area to explore for an agentic AI opportunity is **personalized healthcare management**.
#
# As healthcare systems increasingly shift towards personalized medicine, there is a growing demand for AI solutions that can help individuals manage their health proactively. An agentic AI in this space could function as a comprehensive health assistant that:
#
# 1. **Monitors Health Metrics**: Using wearable devices to track vital signs, activity levels, sleep patterns, and other health indicators in real-time.
#
# 2. **Customized Health Recommendations**: Analyzing individual health data and lifestyle choices to provide tailored suggestions for diet, exercise, medication management, and preventive care.
#
# 3. **Medication Management**: Reminding patients when to take medications, re-ordering prescriptions, and notifying healthcare providers if medication adherence is an issue.
#
# 4. **Coordination of Care**: Facilitating communication and scheduling between healthcare providers and patients, ensuring that care plans are continually adjusted based on patient feedback and health outcomes.
#
# 5. **Behavioral Nudges**: Using behavioral science principles to encourage healthier habits, such as reminders for physical activity, mindfulness exercises, or adherence to treatment protocols.
#
# 6. **Data Management and Privacy**: Ensuring that all personal health data is securely managed and that patients have control over who can access their information.
#
# By leveraging capabilities such as natural language processing, machine learning, and data analytics, an agentic AI could significantly enhance patient engagement, improve health outcomes, and reduce overall healthcare costs. This area not only addresses a critical need but also has the potential for social impact, making it an attractive opportunity for innovation.

# %%
# Then read the business idea:

business_idea = f"Give me pain points int the industry" 

messages = [{"role": "user", "content": business_idea}]

response = generate_chat_completion(messages, deployment_name)

print(response)




# And repeat! In the next message, include the business idea within the message
# Out:
# Identifying pain points in an industry can vary significantly based on the sector in question. However, here are some common pain points that many industries face:
#
# ### 1. **Supply Chain Disruptions**
#    - **Issues**: Unforeseen delays (e.g., global events, natural disasters), fluctuations in demand, and international trade restrictions.
#    - **Impact**: Increased costs, reduced customer satisfaction, and lost sales opportunities.
#
# ### 2. **Labor Shortages**
#    - **Issues**: Difficulty in finding skilled workers, high turnover rates, and competitive job markets.
#    - **Impact**: Lower productivity, increased training costs, and potential for burnout among existing employees.
#
# ### 3. **Regulatory Compliance**
#    - **Issues**: Navigating complex regulations and standards, varied compliance requirements across regions.
#    - **Impact**: Increased administrative costs, risk of penalties, and potential operational delays.
#
# ### 4. **Technology Integration**
#    - **Issues**: Difficulty integrating new technologies with legacy systems, high costs of implementation, and resistance from employees.
#    - **Impact**: Reduced operational efficiency, lost competitive advantage, and potential data security risks.
#
# ### 5. **Customer Expectations**
#    - **Issues**: Keeping up with rapidly changing consumer preferences, demand for personalized experiences, and omnichannel support.
#    - **Impact**: Risk of customer churn, decreased brand loyalty, and challenges in delivering consistent service.
#
# ### 6. **Data Management**
#    - **Issues**: Proper collection, analysis, and use of data, data privacy concerns, and data silos within organizations.
#    - **Impact**: Informed decision-making hindered, inefficient operations, and regulatory compliance risks.
#
# ### 7. **Cost Management**
#    - **Issues**: Rising operational costs, fluctuating raw material prices, and pressure to maintain profitability.
#    - **Impact**: Margin compression, need for frequent pricing adjustments, and potential layoffs or cutbacks.
#
# ### 8. **Market Competition**
#    - **Issues**: Increasing competition from new entrants, disruptive technologies, and price wars.
#    - **Impact**: Loss of market share, diminished profitability, and the need for constant innovation.
#
# ### 9. **Sustainability Concerns**
#    - **Issues**: Pressure to adopt sustainable practices and reduce carbon footprints, evolving customer and regulatory expectations.
#    - **Impact**: Potential for brand damage, increased costs of sustainable materials, and the challenge of aligning operations with goals.
#
# ### 10. **Cybersecurity Threats**
#    - **Issues**: Rising incidents of data breaches, ransomware attacks, and inadequate training in security protocols.
#    - **Impact**: Financial losses, reputational damage, and legal liabilities.
#
# ### 11. **Adaptation to Remote Work**
#    - **Issues**: Managing teams remotely, ensuring collaboration and productivity, and maintaining company culture.
#    - **Impact**: Challenges in communication, potential declines in employee engagement, and the need for new management strategies.
#
# ### 12. **Innovation and R&D**
#    - **Issues**: Balancing investment in innovation with current operational needs, measuring the ROI on R&D efforts.
#    - **Impact**: Slower product development, barriers to entry into new markets, and diminished competitive edge.
#
# ### 13. **Quality Control**
#    - **Issues**: Ensuring consistent product/service quality, managing supplier quality, and addressing defect rates.
#    - **Impact**: Increased returns and waste, damaged reputation, and higher operational costs.
#
# These pain points can serve as areas of opportunity for improvement, innovation, and strategic development depending on the targeted industry.
